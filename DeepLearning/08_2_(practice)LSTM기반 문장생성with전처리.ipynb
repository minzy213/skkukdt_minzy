# %% [markdown]
# # LSTM기반 문장 생성with전처리
# - 예제 : 간단한 노래 가사로 학습
#
# 클래스로 만들어보기

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\user\anaconda3\envs\mzp\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\user\anaconda3\envs\mzp\lib\site-packages (from konlpy) (1.4.1)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\user\anaconda3\envs\mzp\lib\site-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\anaconda3\envs\mzp\lib\site-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\mzp\lib\site-packages (from JPype1>=0.7.0->konlpy) (23.0)

# %%
# 기본 라이브러리
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense, Bidirectional, Dropout

# %%
text = '''그대 기억이 지난 사랑이

내 안을 파고드는 가시가 되어

제발 가라고 아주 가라고

애써도 나를 괴롭히는데

아픈 만큼 너를 잊게 된다면

차라리 앓고 나면 그만인데

가시처럼 깊게 박힌 기억은

아파도 아픈 줄 모르고

그대 기억이 지난 사랑이

내 안을 파고드는 가시가 되어

제발 가라고 아주 가라고'''

# %%
raw_data = text.split("\n\n")
raw_data
# Out:
# ['그대 기억이 지난 사랑이',
#  '내 안을 파고드는 가시가 되어',
#  '제발 가라고 아주 가라고',
#  '애써도 나를 괴롭히는데',
#  '아픈 만큼 너를 잊게 된다면',
#  '차라리 앓고 나면 그만인데',
#  '가시처럼 깊게 박힌 기억은',
#  '아파도 아픈 줄 모르고',
#  '그대 기억이 지난 사랑이',
#  '내 안을 파고드는 가시가 되어',
#  '제발 가라고 아주 가라고']

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(raw_data)

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 32

# %%
print(tokenizer.word_index)
# Out:
# {'가라고': 1, '그대': 2, '기억이': 3, '지난': 4, '사랑이': 5, '내': 6, '안을': 7, '파고드는': 8, '가시가': 9, '되어': 10, '제발': 11, '아주': 12, '아픈': 13, '애써도': 14, '나를': 15, '괴롭히는데': 16, '만큼': 17, '너를': 18, '잊게': 19, '된다면': 20, '차라리': 21, '앓고': 22, '나면': 23, '그만인데': 24, '가시처럼': 25, '깊게': 26, '박힌': 27, '기억은': 28, '아파도': 29, '줄': 30, '모르고': 31}

# %% [markdown]
# ## 훈련 데이터 생성
# raw_data1 = '그대 기억이 지난 사랑이'
# - x1 = '그대', y1 = '기억이'
# - x2 = '그대 기억이', y2 = ' 지난'
# - x3 = '그대 기억이 지난', y3 = '사랑이'

# %% [markdown]
# ### Implementation 1
# - 1단계 : 벡터화
# '그대 기억이 지난 사랑이'
# =>
# [1, 2, 3, 4]
# =>
# [[1, 2],
#  [1, 2, 3],
#  [1, 2, 3, 4]]
#
# - 2단계 : 패딩
# =>
# [[0, 0, 0, 1, 2],
#  [0, 0, 1, 2, 3],
#  [0, 1, 2, 3, 4]]
#
# - 3단계 : x / y 분할
# =>
# x =[[0, 0, 0, 1],
#     [0, 0, 1, 2],
#     [0, 1, 2, 3]]
# y = [2,
#      3,
#      4]

# %%
# 1단계 : 벡터화
# '그대 기억이 지난 사랑이'
# => [1, 2, 3, 4]
# =>
# [[1, 2],
# [1, 2, 3],
# [1, 2, 3, 4]]

sequence_list = []
# 앞에 단어가 들어오면 뒤의 단어가 출력되어야 한다.
# 맨 뒤에 하나가 뒤의 단어(y), 그 앞에 단어들이 앞의 단어(x)

for line in raw_data: # 줄바꿈을 기준으로 문장나누기
    # tokenizer.texts_to_sequences
    encoded = tokenizer.texts_to_sequences([line])[0]
    for cnt in range(1, len(encoded)):
        sequence_list.append(encoded[:cnt + 1])

# %%
# 2단계 : 패딩 (pre)
# =>
MAX_SEQUENCE_LENGTH = 5
# tmp = []
# for seq in sequence_list:
#     tmp.append([0] * (padding - len(seq)) + seq)
# # [[0, 0, 0, 1, 2],
# # [0, 0, 1, 2, 3],
# # [0, 1, 2, 3, 4]]
# sequence_list = tmp

# pad_sequences 사용!!!
padded = pad_sequences(sequence_list, maxlen=MAX_SEQUENCE_LENGTH, padding='pre')

# %%
# 3단계 : origin -> x / y 분할 => x = :-1(마지막 토큰만 제외) / y = -1 (마지막 토큰만)
# =>
padded_array = np.array(padded)
X = padded_array[:, :-1]
y = padded_array[:, -1:].reshape(-1)
print(X)
# x =[[0, 0, 0, 1],
# [0, 0, 1, 2],
# [0, 1, 2, 3]]
# y = [2,
# 3,
# 4]
# Out:
# [[ 0  0  0  2]
#  [ 0  0  2  3]
#  [ 0  2  3  4]
#  [ 0  0  0  6]
#  [ 0  0  6  7]
#  [ 0  6  7  8]
#  [ 6  7  8  9]
#  [ 0  0  0 11]
#  [ 0  0 11  1]
#  [ 0 11  1 12]
#  [ 0  0  0 14]
#  [ 0  0 14 15]
#  [ 0  0  0 13]
#  [ 0  0 13 17]
#  [ 0 13 17 18]
#  [13 17 18 19]
#  [ 0  0  0 21]
#  [ 0  0 21 22]
#  [ 0 21 22 23]
#  [ 0  0  0 25]
#  [ 0  0 25 26]
#  [ 0 25 26 27]
#  [ 0  0  0 29]
#  [ 0  0 29 13]
#  [ 0 29 13 30]
#  [ 0  0  0  2]
#  [ 0  0  2  3]
#  [ 0  2  3  4]
#  [ 0  0  0  6]
#  [ 0  0  6  7]
#  [ 0  6  7  8]
#  [ 6  7  8  9]
#  [ 0  0  0 11]
#  [ 0  0 11  1]
#  [ 0 11  1 12]]

# %%
print('original:\n', padded[:3])
print('X\n', X[:3])
print('y\n', y[:3])
# Out:
# original:
#  [[0 0 0 2 3]
#  [0 0 2 3 4]
#  [0 2 3 4 5]]
# X
#  [[0 0 0 2]
#  [0 0 2 3]
#  [0 2 3 4]]
# y
#  [3 4 5]

# %%
X.shape, y.shape
# Out:
# ((35, 4), (35,))

# %%
y
# Out:
# array([ 3,  4,  5,  7,  8,  9, 10,  1, 12,  1, 15, 16, 17, 18, 19, 20, 22,
#        23, 24, 26, 27, 28, 13, 30, 31,  3,  4,  5,  7,  8,  9, 10,  1, 12,
#         1])

# %% [markdown]
# ## 모델 구축

# %% [markdown]
# ### Implementation 2

# %%
# Functional API

input = tf.keras.Input(shape=(4, ))

# embedding
x = Embedding(len(tokenizer.word_index) + 1, 32)(input)
# lstm
x = LSTM(128)(x)
# dense
output = Dense(32, activation = 'softmax')(x)
 
model = tf.keras.Model(inputs = input, outputs = output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 4)]               0
#
#  embedding (Embedding)       (None, 4, 32)             1024
#
#  lstm (LSTM)                 (None, 128)               82432
#
#  dense (Dense)               (None, 32)                4128
#
# =================================================================
# Total params: 87,584
# Trainable params: 87,584
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer ='adam',
              metrics = ['acc'])

# %%
model.fit(X, y, epochs = 300, verbose = 2)
# Out:
# Epoch 1/300
# 2/2 - 2s - loss: 3.4648 - acc: 0.0857 - 2s/epoch - 1s/step
# Epoch 2/300
# 2/2 - 0s - loss: 3.4583 - acc: 0.1714 - 9ms/epoch - 5ms/step
# Epoch 3/300
# 2/2 - 0s - loss: 3.4537 - acc: 0.1143 - 8ms/epoch - 4ms/step
# Epoch 4/300
# 2/2 - 0s - loss: 3.4490 - acc: 0.1714 - 7ms/epoch - 4ms/step
# Epoch 5/300
# 2/2 - 0s - loss: 3.4448 - acc: 0.1714 - 8ms/epoch - 4ms/step
# Epoch 6/300
# 2/2 - 0s - loss: 3.4404 - acc: 0.1714 - 9ms/epoch - 4ms/step
# Epoch 7/300
# 2/2 - 0s - loss: 3.4358 - acc: 0.1714 - 7ms/epoch - 4ms/step
# Epoch 8/300
# 2/2 - 0s - loss: 3.4312 - acc: 0.1714 - 7ms/epoch - 4ms/step
# Epoch 9/300
# 2/2 - 0s - loss: 3.4260 - acc: 0.1714 - 7ms/epoch - 4ms/step
# Epoch 10/300
# 2/2 - 0s - loss: 3.4201 - acc: 0.1714 - 6ms/epoch - 3ms/step
# Epoch 11/300
# 2/2 - 0s - loss: 3.4133 - acc: 0.1714 - 28ms/epoch - 14ms/step
# Epoch 12/300
# 2/2 - 0s - loss: 3.4056 - acc: 0.1714 - 9ms/epoch - 4ms/step
# Epoch 13/300
# 2/2 - 0s - loss: 3.3959 - acc: 0.1143 - 7ms/epoch - 4ms/step
# Epoch 14/300
# 2/2 - 0s - loss: 3.3853 - acc: 0.1143 - 8ms/epoch - 4ms/step
# Epoch 15/300
# 2/2 - 0s - loss: 3.3735 - acc: 0.1714 - 8ms/epoch - 4ms/step
# Epoch 16/300
# 2/2 - 0s - loss: 3.3584 - acc: 0.1714 - 7ms/epoch - 3ms/step
# Epoch 17/300
# 2/2 - 0s - loss: 3.3422 - acc: 0.1714 - 7ms/epoch - 4ms/step
# Epoch 18/300
# 2/2 - 0s - loss: 3.3218 - acc: 0.1714 - 8ms/epoch - 4ms/step
# Epoch 19/300
# 2/2 - 0s - loss: 3.2969 - acc: 0.1714 - 8ms/epoch - 4ms/step
# Epoch 20/300
# 2/2 - 0s - loss: 3.2692 - acc: 0.1714 - 7ms/epoch - 4ms/step
# Epoch 21/300
# 2/2 - 0s - loss: 3.2346 - acc: 0.1714 - 8ms/epoch - 4ms/step
# Epoch 22/300
# 2/2 - 0s - loss: 3.1958 - acc: 0.1714 - 8ms/epoch - 4ms/step
# Epoch 23/300
# 2/2 - 0s - loss: 3.1551 - acc: 0.1714 - 8ms/epoch - 4ms/step
# Epoch 24/300
# 2/2 - 0s - loss: 3.1135 - acc: 0.1714 - 8ms/epoch - 4ms/step
# Epoch 25/300
# 2/2 - 0s - loss: 3.0703 - acc: 0.1714 - 6ms/epoch - 3ms/step
# Epoch 26/300
# 2/2 - 0s - loss: 3.0428 - acc: 0.1714 - 6ms/epoch - 3ms/step
# Epoch 27/300
# 2/2 - 0s - loss: 3.0150 - acc: 0.1714 - 9ms/epoch - 5ms/step
# Epoch 28/300
# 2/2 - 0s - loss: 2.9889 - acc: 0.1714 - 32ms/epoch - 16ms/step
# Epoch 29/300
# 2/2 - 0s - loss: 2.9614 - acc: 0.1714 - 10ms/epoch - 5ms/step
# Epoch 30/300
# 2/2 - 0s - loss: 2.9348 - acc: 0.1714 - 7ms/epoch - 4ms/step
# Epoch 31/300
# 2/2 - 0s - loss: 2.9129 - acc: 0.1714 - 7ms/epoch - 4ms/step
# Epoch 32/300
# 2/2 - 0s - loss: 2.8861 - acc: 0.2286 - 6ms/epoch - 3ms/step
# Epoch 33/300
# 2/2 - 0s - loss: 2.8559 - acc: 0.2286 - 7ms/epoch - 4ms/step
# Epoch 34/300
# 2/2 - 0s - loss: 2.8240 - acc: 0.2286 - 7ms/epoch - 4ms/step
# Epoch 35/300
# 2/2 - 0s - loss: 2.7884 - acc: 0.2286 - 6ms/epoch - 3ms/step
# Epoch 36/300
# 2/2 - 0s - loss: 2.7475 - acc: 0.2286 - 7ms/epoch - 4ms/step
# Epoch 37/300
# 2/2 - 0s - loss: 2.7052 - acc: 0.2286 - 7ms/epoch - 4ms/step
# Epoch 38/300
# 2/2 - 0s - loss: 2.6619 - acc: 0.2286 - 6ms/epoch - 3ms/step
# Epoch 39/300
# 2/2 - 0s - loss: 2.6201 - acc: 0.2286 - 7ms/epoch - 4ms/step
# Epoch 40/300
# 2/2 - 0s - loss: 2.5775 - acc: 0.2857 - 9ms/epoch - 5ms/step
# Epoch 41/300
# 2/2 - 0s - loss: 2.5306 - acc: 0.2857 - 9ms/epoch - 4ms/step
# Epoch 42/300
# 2/2 - 0s - loss: 2.4867 - acc: 0.3429 - 7ms/epoch - 4ms/step
# Epoch 43/300
# 2/2 - 0s - loss: 2.4398 - acc: 0.4000 - 7ms/epoch - 4ms/step
# Epoch 44/300
# 2/2 - 0s - loss: 2.3974 - acc: 0.4000 - 10ms/epoch - 5ms/step
# Epoch 45/300
# 2/2 - 0s - loss: 2.3555 - acc: 0.4000 - 16ms/epoch - 8ms/step
# Epoch 46/300
# 2/2 - 0s - loss: 2.3161 - acc: 0.4000 - 8ms/epoch - 4ms/step
# Epoch 47/300
# 2/2 - 0s - loss: 2.2767 - acc: 0.4000 - 10ms/epoch - 5ms/step
# Epoch 48/300
# 2/2 - 0s - loss: 2.2441 - acc: 0.4000 - 7ms/epoch - 4ms/step
# Epoch 49/300
# 2/2 - 0s - loss: 2.2114 - acc: 0.3429 - 7ms/epoch - 4ms/step
# Epoch 50/300
# 2/2 - 0s - loss: 2.1783 - acc: 0.4000 - 6ms/epoch - 3ms/step
# Epoch 51/300
# 2/2 - 0s - loss: 2.1436 - acc: 0.4000 - 7ms/epoch - 4ms/step
# Epoch 52/300
# 2/2 - 0s - loss: 2.1065 - acc: 0.4571 - 8ms/epoch - 4ms/step
# Epoch 53/300
# 2/2 - 0s - loss: 2.0656 - acc: 0.4571 - 7ms/epoch - 4ms/step
# Epoch 54/300
# 2/2 - 0s - loss: 2.0262 - acc: 0.5143 - 8ms/epoch - 4ms/step
# Epoch 55/300
# 2/2 - 0s - loss: 1.9891 - acc: 0.5143 - 8ms/epoch - 4ms/step
# Epoch 56/300
# 2/2 - 0s - loss: 1.9581 - acc: 0.5143 - 7ms/epoch - 4ms/step
# Epoch 57/300
# 2/2 - 0s - loss: 1.9307 - acc: 0.5143 - 9ms/epoch - 5ms/step
# Epoch 58/300
# 2/2 - 0s - loss: 1.9032 - acc: 0.5143 - 7ms/epoch - 4ms/step
# Epoch 59/300
# 2/2 - 0s - loss: 1.8769 - acc: 0.5429 - 15ms/epoch - 7ms/step
# Epoch 60/300
# 2/2 - 0s - loss: 1.8501 - acc: 0.5429 - 10ms/epoch - 5ms/step
# Epoch 61/300
# 2/2 - 0s - loss: 1.8188 - acc: 0.5429 - 9ms/epoch - 4ms/step
# Epoch 62/300
# 2/2 - 0s - loss: 1.7868 - acc: 0.5714 - 7ms/epoch - 3ms/step
# Epoch 63/300
# 2/2 - 0s - loss: 1.7578 - acc: 0.5714 - 7ms/epoch - 4ms/step
# Epoch 64/300
# 2/2 - 0s - loss: 1.7303 - acc: 0.5714 - 7ms/epoch - 3ms/step
# Epoch 65/300
# 2/2 - 0s - loss: 1.7026 - acc: 0.5714 - 8ms/epoch - 4ms/step
# Epoch 66/300
# 2/2 - 0s - loss: 1.6781 - acc: 0.5429 - 7ms/epoch - 3ms/step
# Epoch 67/300
# 2/2 - 0s - loss: 1.6513 - acc: 0.5143 - 8ms/epoch - 4ms/step
# Epoch 68/300
# 2/2 - 0s - loss: 1.6145 - acc: 0.5143 - 6ms/epoch - 3ms/step
# Epoch 69/300
# 2/2 - 0s - loss: 1.5761 - acc: 0.5714 - 9ms/epoch - 5ms/step
# Epoch 70/300
# 2/2 - 0s - loss: 1.5360 - acc: 0.6571 - 8ms/epoch - 4ms/step
# Epoch 71/300
# 2/2 - 0s - loss: 1.4966 - acc: 0.6571 - 7ms/epoch - 4ms/step
# Epoch 72/300
# 2/2 - 0s - loss: 1.4647 - acc: 0.6571 - 8ms/epoch - 4ms/step
# Epoch 73/300
# 2/2 - 0s - loss: 1.4482 - acc: 0.6571 - 7ms/epoch - 4ms/step
# Epoch 74/300
# 2/2 - 0s - loss: 1.4344 - acc: 0.6571 - 14ms/epoch - 7ms/step
# Epoch 75/300
# 2/2 - 0s - loss: 1.4104 - acc: 0.6571 - 14ms/epoch - 7ms/step
# Epoch 76/300
# 2/2 - 0s - loss: 1.3844 - acc: 0.6571 - 11ms/epoch - 5ms/step
# Epoch 77/300
# 2/2 - 0s - loss: 1.3601 - acc: 0.6571 - 7ms/epoch - 3ms/step
# Epoch 78/300
# 2/2 - 0s - loss: 1.3300 - acc: 0.7143 - 7ms/epoch - 4ms/step
# Epoch 79/300
# 2/2 - 0s - loss: 1.3095 - acc: 0.7143 - 6ms/epoch - 3ms/step
# Epoch 80/300
# 2/2 - 0s - loss: 1.2922 - acc: 0.7143 - 7ms/epoch - 4ms/step
# Epoch 81/300
# 2/2 - 0s - loss: 1.2648 - acc: 0.6571 - 7ms/epoch - 4ms/step
# Epoch 82/300
# 2/2 - 0s - loss: 1.2453 - acc: 0.6857 - 7ms/epoch - 4ms/step
# Epoch 83/300
# 2/2 - 0s - loss: 1.2229 - acc: 0.7429 - 7ms/epoch - 3ms/step
# Epoch 84/300
# 2/2 - 0s - loss: 1.1967 - acc: 0.8000 - 7ms/epoch - 4ms/step
# Epoch 85/300
# 2/2 - 0s - loss: 1.1733 - acc: 0.7429 - 6ms/epoch - 3ms/step
# Epoch 86/300
# 2/2 - 0s - loss: 1.1451 - acc: 0.8000 - 8ms/epoch - 4ms/step
# Epoch 87/300
# 2/2 - 0s - loss: 1.1170 - acc: 0.7714 - 9ms/epoch - 4ms/step
# Epoch 88/300
# 2/2 - 0s - loss: 1.0919 - acc: 0.7714 - 32ms/epoch - 16ms/step
# Epoch 89/300
# 2/2 - 0s - loss: 1.0718 - acc: 0.7714 - 10ms/epoch - 5ms/step
# Epoch 90/300
# 2/2 - 0s - loss: 1.0420 - acc: 0.7714 - 8ms/epoch - 4ms/step
# Epoch 91/300
# 2/2 - 0s - loss: 1.0145 - acc: 0.7714 - 7ms/epoch - 4ms/step
# Epoch 92/300
# 2/2 - 0s - loss: 1.0050 - acc: 0.8000 - 8ms/epoch - 4ms/step
# Epoch 93/300
# 2/2 - 0s - loss: 1.0022 - acc: 0.8000 - 8ms/epoch - 4ms/step
# Epoch 94/300
# 2/2 - 0s - loss: 0.9786 - acc: 0.8000 - 8ms/epoch - 4ms/step
# Epoch 95/300
# 2/2 - 0s - loss: 0.9524 - acc: 0.8000 - 8ms/epoch - 4ms/step
# Epoch 96/300
# 2/2 - 0s - loss: 0.9252 - acc: 0.7714 - 7ms/epoch - 3ms/step
# Epoch 97/300
# 2/2 - 0s - loss: 0.8964 - acc: 0.8000 - 8ms/epoch - 4ms/step
# Epoch 98/300
# 2/2 - 0s - loss: 0.8709 - acc: 0.8857 - 8ms/epoch - 4ms/step
# Epoch 99/300
# 2/2 - 0s - loss: 0.8566 - acc: 0.8571 - 8ms/epoch - 4ms/step
# Epoch 100/300
# 2/2 - 0s - loss: 0.8446 - acc: 0.8286 - 7ms/epoch - 3ms/step
# Epoch 101/300
# 2/2 - 0s - loss: 0.8257 - acc: 0.8857 - 15ms/epoch - 8ms/step
# Epoch 102/300
# 2/2 - 0s - loss: 0.8137 - acc: 0.8286 - 14ms/epoch - 7ms/step
# Epoch 103/300
# 2/2 - 0s - loss: 0.7924 - acc: 0.8286 - 8ms/epoch - 4ms/step
# Epoch 104/300
# 2/2 - 0s - loss: 0.7650 - acc: 0.8857 - 9ms/epoch - 5ms/step
# Epoch 105/300
# 2/2 - 0s - loss: 0.7468 - acc: 0.8857 - 8ms/epoch - 4ms/step
# Epoch 106/300
# 2/2 - 0s - loss: 0.7307 - acc: 0.8857 - 7ms/epoch - 4ms/step
# Epoch 107/300
# 2/2 - 0s - loss: 0.7239 - acc: 0.8286 - 8ms/epoch - 4ms/step
# Epoch 108/300
# 2/2 - 0s - loss: 0.7242 - acc: 0.8286 - 8ms/epoch - 4ms/step
# Epoch 109/300
# 2/2 - 0s - loss: 0.7205 - acc: 0.8286 - 6ms/epoch - 3ms/step
# Epoch 110/300
# 2/2 - 0s - loss: 0.7072 - acc: 0.8000 - 8ms/epoch - 4ms/step
# Epoch 111/300
# 2/2 - 0s - loss: 0.6838 - acc: 0.8857 - 9ms/epoch - 4ms/step
# Epoch 112/300
# 2/2 - 0s - loss: 0.6564 - acc: 0.9143 - 8ms/epoch - 4ms/step
# Epoch 113/300
# 2/2 - 0s - loss: 0.6326 - acc: 0.8857 - 9ms/epoch - 5ms/step
# Epoch 114/300
# 2/2 - 0s - loss: 0.6108 - acc: 0.9429 - 7ms/epoch - 4ms/step
# Epoch 115/300
# 2/2 - 0s - loss: 0.6230 - acc: 0.8857 - 19ms/epoch - 10ms/step
# Epoch 116/300
# 2/2 - 0s - loss: 0.6221 - acc: 0.8857 - 8ms/epoch - 4ms/step
# Epoch 117/300
# 2/2 - 0s - loss: 0.6134 - acc: 0.8857 - 14ms/epoch - 7ms/step
# Epoch 118/300
# 2/2 - 0s - loss: 0.5981 - acc: 0.8857 - 7ms/epoch - 3ms/step
# Epoch 119/300
# 2/2 - 0s - loss: 0.5740 - acc: 0.8857 - 8ms/epoch - 4ms/step
# Epoch 120/300
# 2/2 - 0s - loss: 0.5520 - acc: 0.8857 - 8ms/epoch - 4ms/step
# Epoch 121/300
# 2/2 - 0s - loss: 0.5311 - acc: 0.9143 - 8ms/epoch - 4ms/step
# Epoch 122/300
# 2/2 - 0s - loss: 0.5261 - acc: 0.8857 - 7ms/epoch - 3ms/step
# Epoch 123/300
# 2/2 - 0s - loss: 0.5132 - acc: 0.8857 - 7ms/epoch - 3ms/step
# Epoch 124/300
# 2/2 - 0s - loss: 0.5111 - acc: 0.9143 - 7ms/epoch - 4ms/step
# Epoch 125/300
# 2/2 - 0s - loss: 0.5116 - acc: 0.9143 - 7ms/epoch - 4ms/step
# Epoch 126/300
# 2/2 - 0s - loss: 0.5125 - acc: 0.9429 - 7ms/epoch - 4ms/step
# Epoch 127/300
# 2/2 - 0s - loss: 0.5147 - acc: 0.9429 - 7ms/epoch - 4ms/step
# Epoch 128/300
# 2/2 - 0s - loss: 0.5115 - acc: 0.9429 - 8ms/epoch - 4ms/step
# Epoch 129/300
# 2/2 - 0s - loss: 0.5002 - acc: 0.9429 - 8ms/epoch - 4ms/step
# Epoch 130/300
# 2/2 - 0s - loss: 0.4873 - acc: 0.9143 - 7ms/epoch - 4ms/step
# Epoch 131/300
# 2/2 - 0s - loss: 0.4787 - acc: 0.8857 - 17ms/epoch - 8ms/step
# Epoch 132/300
# 2/2 - 0s - loss: 0.4703 - acc: 0.8286 - 11ms/epoch - 5ms/step
# Epoch 133/300
# 2/2 - 0s - loss: 0.4690 - acc: 0.8286 - 10ms/epoch - 5ms/step
# Epoch 134/300
# 2/2 - 0s - loss: 0.4680 - acc: 0.8286 - 8ms/epoch - 4ms/step
# Epoch 135/300
# 2/2 - 0s - loss: 0.4640 - acc: 0.8286 - 7ms/epoch - 4ms/step
# Epoch 136/300
# 2/2 - 0s - loss: 0.4571 - acc: 0.8571 - 9ms/epoch - 5ms/step
# Epoch 137/300
# 2/2 - 0s - loss: 0.4385 - acc: 0.8857 - 7ms/epoch - 4ms/step
# Epoch 138/300
# 2/2 - 0s - loss: 0.4156 - acc: 0.9143 - 7ms/epoch - 4ms/step
# Epoch 139/300
# 2/2 - 0s - loss: 0.3963 - acc: 0.9429 - 7ms/epoch - 4ms/step
# Epoch 140/300
# 2/2 - 0s - loss: 0.3948 - acc: 0.9714 - 7ms/epoch - 3ms/step
# Epoch 141/300
# 2/2 - 0s - loss: 0.3963 - acc: 0.9714 - 9ms/epoch - 4ms/step
# Epoch 142/300
# 2/2 - 0s - loss: 0.3966 - acc: 0.9714 - 8ms/epoch - 4ms/step
# Epoch 143/300
# 2/2 - 0s - loss: 0.3960 - acc: 0.9429 - 6ms/epoch - 3ms/step
# Epoch 144/300
# 2/2 - 0s - loss: 0.3949 - acc: 0.9429 - 8ms/epoch - 4ms/step
# Epoch 145/300
# 2/2 - 0s - loss: 0.3878 - acc: 0.9429 - 12ms/epoch - 6ms/step
# Epoch 146/300
# 2/2 - 0s - loss: 0.3771 - acc: 0.9429 - 10ms/epoch - 5ms/step
# Epoch 147/300
# 2/2 - 0s - loss: 0.3595 - acc: 0.9714 - 7ms/epoch - 3ms/step
# Epoch 148/300
# 2/2 - 0s - loss: 0.3461 - acc: 0.9429 - 9ms/epoch - 5ms/step
# Epoch 149/300
# 2/2 - 0s - loss: 0.3444 - acc: 0.9143 - 7ms/epoch - 4ms/step
# Epoch 150/300
# 2/2 - 0s - loss: 0.3499 - acc: 0.8857 - 7ms/epoch - 4ms/step
# Epoch 151/300
# 2/2 - 0s - loss: 0.3549 - acc: 0.8857 - 6ms/epoch - 3ms/step
# Epoch 152/300
# 2/2 - 0s - loss: 0.3560 - acc: 0.8857 - 7ms/epoch - 4ms/step
# Epoch 153/300
# 2/2 - 0s - loss: 0.3499 - acc: 0.9143 - 6ms/epoch - 3ms/step
# Epoch 154/300
# 2/2 - 0s - loss: 0.3422 - acc: 0.9143 - 7ms/epoch - 3ms/step
# Epoch 155/300
# 2/2 - 0s - loss: 0.3318 - acc: 0.9143 - 8ms/epoch - 4ms/step
# Epoch 156/300
# 2/2 - 0s - loss: 0.3237 - acc: 0.9143 - 7ms/epoch - 4ms/step
# Epoch 157/300
# 2/2 - 0s - loss: 0.3133 - acc: 0.9143 - 8ms/epoch - 4ms/step
# Epoch 158/300
# 2/2 - 0s - loss: 0.3116 - acc: 0.9714 - 6ms/epoch - 3ms/step
# Epoch 159/300
# 2/2 - 0s - loss: 0.3067 - acc: 0.9714 - 9ms/epoch - 4ms/step
# Epoch 160/300
# 2/2 - 0s - loss: 0.3072 - acc: 0.9429 - 11ms/epoch - 5ms/step
# Epoch 161/300
# 2/2 - 0s - loss: 0.3076 - acc: 0.9429 - 7ms/epoch - 3ms/step
# Epoch 162/300
# 2/2 - 0s - loss: 0.3094 - acc: 0.9143 - 8ms/epoch - 4ms/step
# Epoch 163/300
# 2/2 - 0s - loss: 0.3089 - acc: 0.9143 - 8ms/epoch - 4ms/step
# Epoch 164/300
# 2/2 - 0s - loss: 0.2973 - acc: 0.9143 - 8ms/epoch - 4ms/step
# Epoch 165/300
# 2/2 - 0s - loss: 0.2800 - acc: 0.9714 - 8ms/epoch - 4ms/step
# Epoch 166/300
# 2/2 - 0s - loss: 0.2707 - acc: 0.9714 - 7ms/epoch - 4ms/step
# Epoch 167/300
# 2/2 - 0s - loss: 0.2661 - acc: 0.9714 - 6ms/epoch - 3ms/step
# Epoch 168/300
# 2/2 - 0s - loss: 0.2630 - acc: 0.9714 - 7ms/epoch - 4ms/step
# Epoch 169/300
# 2/2 - 0s - loss: 0.2593 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 170/300
# 2/2 - 0s - loss: 0.2535 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 171/300
# 2/2 - 0s - loss: 0.2454 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 172/300
# 2/2 - 0s - loss: 0.2410 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 173/300
# 2/2 - 0s - loss: 0.2408 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 174/300
# 2/2 - 0s - loss: 0.2441 - acc: 1.0000 - 14ms/epoch - 7ms/step
# Epoch 175/300
# 2/2 - 0s - loss: 0.2445 - acc: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 176/300
# 2/2 - 0s - loss: 0.2417 - acc: 0.9429 - 7ms/epoch - 4ms/step
# Epoch 177/300
# 2/2 - 0s - loss: 0.2334 - acc: 0.9714 - 9ms/epoch - 5ms/step
# Epoch 178/300
# 2/2 - 0s - loss: 0.2264 - acc: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 179/300
# 2/2 - 0s - loss: 0.2241 - acc: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 180/300
# 2/2 - 0s - loss: 0.2237 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 181/300
# 2/2 - 0s - loss: 0.2232 - acc: 1.0000 - 7ms/epoch - 3ms/step
# Epoch 182/300
# 2/2 - 0s - loss: 0.2182 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 183/300
# 2/2 - 0s - loss: 0.2099 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 184/300
# 2/2 - 0s - loss: 0.2025 - acc: 1.0000 - 7ms/epoch - 3ms/step
# Epoch 185/300
# 2/2 - 0s - loss: 0.2022 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 186/300
# 2/2 - 0s - loss: 0.1994 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 187/300
# 2/2 - 0s - loss: 0.1970 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 188/300
# 2/2 - 0s - loss: 0.1961 - acc: 1.0000 - 16ms/epoch - 8ms/step
# Epoch 189/300
# 2/2 - 0s - loss: 0.1950 - acc: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 190/300
# 2/2 - 0s - loss: 0.1924 - acc: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 191/300
# 2/2 - 0s - loss: 0.1886 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 192/300
# 2/2 - 0s - loss: 0.1854 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 193/300
# 2/2 - 0s - loss: 0.1851 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 194/300
# 2/2 - 0s - loss: 0.1848 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 195/300
# 2/2 - 0s - loss: 0.1797 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 196/300
# 2/2 - 0s - loss: 0.1777 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 197/300
# 2/2 - 0s - loss: 0.1767 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 198/300
# 2/2 - 0s - loss: 0.1725 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 199/300
# 2/2 - 0s - loss: 0.1678 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 200/300
# 2/2 - 0s - loss: 0.1656 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 201/300
# 2/2 - 0s - loss: 0.1646 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 202/300
# 2/2 - 0s - loss: 0.1620 - acc: 1.0000 - 13ms/epoch - 7ms/step
# Epoch 203/300
# 2/2 - 0s - loss: 0.1572 - acc: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 204/300
# 2/2 - 0s - loss: 0.1507 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 205/300
# 2/2 - 0s - loss: 0.1456 - acc: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 206/300
# 2/2 - 0s - loss: 0.1446 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 207/300
# 2/2 - 0s - loss: 0.1454 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 208/300
# 2/2 - 0s - loss: 0.1429 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 209/300
# 2/2 - 0s - loss: 0.1404 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 210/300
# 2/2 - 0s - loss: 0.1353 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 211/300
# 2/2 - 0s - loss: 0.1300 - acc: 1.0000 - 9ms/epoch - 5ms/step
# Epoch 212/300
# 2/2 - 0s - loss: 0.1286 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 213/300
# 2/2 - 0s - loss: 0.1258 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 214/300
# 2/2 - 0s - loss: 0.1236 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 215/300
# 2/2 - 0s - loss: 0.1211 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 216/300
# 2/2 - 0s - loss: 0.1185 - acc: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 217/300
# 2/2 - 0s - loss: 0.1158 - acc: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 218/300
# 2/2 - 0s - loss: 0.1135 - acc: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 219/300
# 2/2 - 0s - loss: 0.1116 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 220/300
# 2/2 - 0s - loss: 0.1101 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 221/300
# 2/2 - 0s - loss: 0.1084 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 222/300
# 2/2 - 0s - loss: 0.1060 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 223/300
# 2/2 - 0s - loss: 0.1037 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 224/300
# 2/2 - 0s - loss: 0.1027 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 225/300
# 2/2 - 0s - loss: 0.1008 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 226/300
# 2/2 - 0s - loss: 0.0986 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 227/300
# 2/2 - 0s - loss: 0.0979 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 228/300
# 2/2 - 0s - loss: 0.0981 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 229/300
# 2/2 - 0s - loss: 0.0965 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 230/300
# 2/2 - 0s - loss: 0.0964 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 231/300
# 2/2 - 0s - loss: 0.0954 - acc: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 232/300
# 2/2 - 0s - loss: 0.0947 - acc: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 233/300
# 2/2 - 0s - loss: 0.0931 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 234/300
# 2/2 - 0s - loss: 0.0904 - acc: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 235/300
# 2/2 - 0s - loss: 0.0878 - acc: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 236/300
# 2/2 - 0s - loss: 0.0860 - acc: 1.0000 - 7ms/epoch - 3ms/step
# Epoch 237/300
# 2/2 - 0s - loss: 0.0849 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 238/300
# 2/2 - 0s - loss: 0.0847 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 239/300
# 2/2 - 0s - loss: 0.0838 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 240/300
# 2/2 - 0s - loss: 0.0823 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 241/300
# 2/2 - 0s - loss: 0.0804 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 242/300
# 2/2 - 0s - loss: 0.0782 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 243/300
# 2/2 - 0s - loss: 0.0766 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 244/300
# 2/2 - 0s - loss: 0.0760 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 245/300
# 2/2 - 0s - loss: 0.0756 - acc: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 246/300
# 2/2 - 0s - loss: 0.0751 - acc: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 247/300
# 2/2 - 0s - loss: 0.0738 - acc: 1.0000 - 7ms/epoch - 3ms/step
# Epoch 248/300
# 2/2 - 0s - loss: 0.0716 - acc: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 249/300
# 2/2 - 0s - loss: 0.0693 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 250/300
# 2/2 - 0s - loss: 0.0683 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 251/300
# 2/2 - 0s - loss: 0.0694 - acc: 1.0000 - 7ms/epoch - 3ms/step
# Epoch 252/300
# 2/2 - 0s - loss: 0.0699 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 253/300
# 2/2 - 0s - loss: 0.0687 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 254/300
# 2/2 - 0s - loss: 0.0672 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 255/300
# 2/2 - 0s - loss: 0.0661 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 256/300
# 2/2 - 0s - loss: 0.0653 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 257/300
# 2/2 - 0s - loss: 0.0644 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 258/300
# 2/2 - 0s - loss: 0.0634 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 259/300
# 2/2 - 0s - loss: 0.0622 - acc: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 260/300
# 2/2 - 0s - loss: 0.0607 - acc: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 261/300
# 2/2 - 0s - loss: 0.0608 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 262/300
# 2/2 - 0s - loss: 0.0606 - acc: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 263/300
# 2/2 - 0s - loss: 0.0605 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 264/300
# 2/2 - 0s - loss: 0.0600 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 265/300
# 2/2 - 0s - loss: 0.0592 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 266/300
# 2/2 - 0s - loss: 0.0582 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 267/300
# 2/2 - 0s - loss: 0.0573 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 268/300
# 2/2 - 0s - loss: 0.0564 - acc: 1.0000 - 7ms/epoch - 3ms/step
# Epoch 269/300
# 2/2 - 0s - loss: 0.0555 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 270/300
# 2/2 - 0s - loss: 0.0547 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 271/300
# 2/2 - 0s - loss: 0.0539 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 272/300
# 2/2 - 0s - loss: 0.0532 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 273/300
# 2/2 - 0s - loss: 0.0526 - acc: 1.0000 - 30ms/epoch - 15ms/step
# Epoch 274/300
# 2/2 - 0s - loss: 0.0522 - acc: 1.0000 - 13ms/epoch - 7ms/step
# Epoch 275/300
# 2/2 - 0s - loss: 0.0514 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 276/300
# 2/2 - 0s - loss: 0.0511 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 277/300
# 2/2 - 0s - loss: 0.0504 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 278/300
# 2/2 - 0s - loss: 0.0497 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 279/300
# 2/2 - 0s - loss: 0.0489 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 280/300
# 2/2 - 0s - loss: 0.0479 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 281/300
# 2/2 - 0s - loss: 0.0470 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 282/300
# 2/2 - 0s - loss: 0.0460 - acc: 1.0000 - 9ms/epoch - 5ms/step
# Epoch 283/300
# 2/2 - 0s - loss: 0.0458 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 284/300
# 2/2 - 0s - loss: 0.0449 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 285/300
# 2/2 - 0s - loss: 0.0443 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 286/300
# 2/2 - 0s - loss: 0.0440 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 287/300
# 2/2 - 0s - loss: 0.0436 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 288/300
# 2/2 - 0s - loss: 0.0431 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 289/300
# 2/2 - 0s - loss: 0.0426 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 290/300
# 2/2 - 0s - loss: 0.0420 - acc: 1.0000 - 18ms/epoch - 9ms/step
# Epoch 291/300
# 2/2 - 0s - loss: 0.0414 - acc: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 292/300
# 2/2 - 0s - loss: 0.0408 - acc: 1.0000 - 9ms/epoch - 5ms/step
# Epoch 293/300
# 2/2 - 0s - loss: 0.0402 - acc: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 294/300
# 2/2 - 0s - loss: 0.0399 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 295/300
# 2/2 - 0s - loss: 0.0393 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 296/300
# 2/2 - 0s - loss: 0.0388 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 297/300
# 2/2 - 0s - loss: 0.0387 - acc: 1.0000 - 6ms/epoch - 3ms/step
# Epoch 298/300
# 2/2 - 0s - loss: 0.0384 - acc: 1.0000 - 8ms/epoch - 4ms/step
# Epoch 299/300
# 2/2 - 0s - loss: 0.0381 - acc: 1.0000 - 7ms/epoch - 4ms/step
# Epoch 300/300
# 2/2 - 0s - loss: 0.0378 - acc: 1.0000 - 6ms/epoch - 3ms/step

# %%
y_pred = model.predict(X[0:1])
# Out:
# 1/1 [==============================] - 0s 398ms/step

# %%
# vocab들 중에 각 단어일 확률
np.argmax(y_pred)
# Out:
# 3

# %%
tokenizer.index_word[3]
# Out:
# '기억이'

# %% [markdown]
# ## 문장 생성 함수 구축

# %% [markdown]
# ### Implementation 3

# %%
tokenizer.word_index.items()
# Out:
# dict_items([('가라고', 1), ('그대', 2), ('기억이', 3), ('지난', 4), ('사랑이', 5), ('내', 6), ('안을', 7), ('파고드는', 8), ('가시가', 9), ('되어', 10), ('제발', 11), ('아주', 12), ('아픈', 13), ('애써도', 14), ('나를', 15), ('괴롭히는데', 16), ('만큼', 17), ('너를', 18), ('잊게', 19), ('된다면', 20), ('차라리', 21), ('앓고', 22), ('나면', 23), ('그만인데', 24), ('가시처럼', 25), ('깊게', 26), ('박힌', 27), ('기억은', 28), ('아파도', 29), ('줄', 30), ('모르고', 31)])

# %%
def sentence_generation(model, tokenizer, current_word, n): # 모델, 토크나이저, 현재 단어, 반복할 횟수
    init_word = current_word
    sentence = ''

    # n번 반복
    for _ in range(n):
        # 현재 단어에 대한 정수 인코딩과 패딩
        encoded = tokenizer.texts_to_sequences([current_word])[0]
        padded = pad_sequences([encoded], maxlen=MAX_SEQUENCE_LENGTH, padding='pre')

        # 입력한 X(현재 단어)에 대해서 Y를 예측하고 Y(예측한 단어)를 result에 저장.
        # model.predict / np.argmax
        y_pred = model.predict(padded)
        result = tokenizer.index_word[np.argmax(y_pred)]

        for word, index in tokenizer.word_index.items():
            # 만약 예측한 단어와 인덱스와 동일한 단어가 있다면 break
            if index == result:
                break

        # 현재 단어 + ' ' + 예측 단어를 현재 단어로 변경
        current_word += ' ' + result
        # 예측 단어를 문장에 저장

    return current_word

# %%
print(sentence_generation(model, tokenizer, '제발', 4))
# Out:
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 제발 가라고 아주 가라고 가라고

# %%
print(sentence_generation(model, tokenizer, '그냥', 5))
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 그냥 가라고 앓고 앓고 나면 나면

# %% [markdown]
# ## NSMC 영화 리뷰 데이터로 수행

# %%
# 영화 리뷰 데이터
train = pd.read_csv('https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt', header=0, delimiter='\t' ,quoting=3)
test = pd.read_csv('https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt', header=0, delimiter='\t' ,quoting=3)

# %%
train = train.dropna()

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train['document'].values)
vocab_size = len(tokenizer.word_index) + 1

# %%
sequence_list = []
lenn = []
for value in train['document'].values:
    sequence_list.append(tokenizer.texts_to_sequences([value])[0])
    lenn.append(len(tokenizer.texts_to_sequences([value])[0]))

# %%
padded = pad_sequences(sequence_list, maxlen=10, padding='pre')

# %%
X = padded[:, :-1]
y = padded[:, -1:]

# %%
# Functional API

input = tf.keras.Input(shape=(9, ))

# embedding
x = Embedding(vocab_size, 100)(input)
# lstm
x = LSTM(128)(x)
# dense
output = Dense(vocab_size, activation = 'softmax')(x)
 
model = tf.keras.Model(inputs = input, outputs = output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 9)]               0
#
#  embedding_1 (Embedding)     (None, 9, 100)            3200
#
#  lstm_1 (LSTM)               (None, 128)               117248
#
#  dense_1 (Dense)             (None, 32)                4128
#
# =================================================================
# Total params: 124,576
# Trainable params: 124,576
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer ='adam',
              metrics = ['acc'])

# %% [markdown]
# ## 뉴스 기사 데이터로 수행

# %%
# 뉴스 기사 데이터
# !pip install -U --no-cache-dir gdown --pre
# !gdown --no-cookies --id 1KuBG40WNpVPV1ilfGaiCI2D3l8JVSfbS
