# %% [markdown]
# ## BERT로 증강해보기
#
# https://github.com/seoyeon9646/MLM-data-augmentation
# https://huggingface.co/seoyeon96/KcELECTRA-MLM?text=The+goal+of+life+is+%5BMASK%5D.
# https://velog.io/@kimhwangdae/Week9-Huggingface
# https://heekangpark.github.io/nlp/huggingface-bert

# %%
# !pip install torch --extra-index-url https://download.pytorch.org/whl/cu116

# %%
# !pip install ipywidgets

# %%
# !pip install tensorflow
# Out:
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/9e/b8/ed5f794359d05cd0bffb894c6418da87b93016ee17b669d55c45d1bd5d5b/tensorflow-2.13.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.13.0 from https://files.pythonhosted.org/packages/2f/2f/3c84f675931ce3bcbc7e23acbba1e5d7f05ce769adab48322de57a9f5928/tensorflow_intel-2.13.0-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/126.5 kB ? eta -:--:--
#      ------------------ -------------------- 61.4/126.5 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 126.5/126.5 kB 1.9 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for flatbuffers>=23.1.21 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
# ...

# %%
import transformers
from transformers import AutoTokenizer, TFAutoModel

# %%
model = transformers.TFAutoModel.from_pretrained("seoyeon96/KcELECTRA-MLM")
tokenizer = transformers.AutoTokenizer.from_pretrained("seoyeon96/KcELECTRA-MLM")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\code\skkukdt_minzy\DeepLearning\bert_augmentation.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/code/skkukdt_minzy/DeepLearning/bert_augmentation.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> model = transformers.TFAutoModel.from_pretrained("seoyeon96/KcELECTRA-MLM")
#       <a href='vscode-notebook-cell:/c%3A/code/skkukdt_minzy/DeepLearning/bert_augmentation.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> tokenizer = transformers.AutoTokenizer.from_pretrained("seoyeon96/KcELECTRA-MLM")
#
# AttributeError: module 'transformers' has no attribute 'TFAutoModel'
