# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# # RNN 이해하기

# %% [markdown]
# RNN의 input, output, weight을 이해해봅시다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %% [markdown]
# ### 문제1-1

# %% [markdown]
# 모델 summary를 보고 생각해봅시다.
# - input은 어떤 모양인가요?
# - output은 어떤 모양인가요?
# - weights 개수는?

# %%
model = Sequential()
model.add(SimpleRNN(5, input_shape=(2,10))) # timesteps=2, n_feature=10

model.summary()
# Output Shape = batch_size=None, n_feature=5
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_13 (SimpleRNN)   (None, 5)                 80
#
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 문제1-2

# %% [markdown]
# 모델 summary를 보고 생각해봅시다.
# - input은 어떤 모양인가요?
# - output은 어떤 모양인가요?
# - weights 개수는?

# %%
model = Sequential()
model.add(SimpleRNN(5, input_shape=(2,10), return_sequences=True)) # timesteps=2, n_feature=10

model.summary()
# Output Shape = batch_size=None, timesteps=2, n_feature=5
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 2, 5)              80
#
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 문제 1-3

# %% [markdown]
# 모델 summary를 보고 생각해봅시다.
# - input은 어떤 모양인가요?
# - output은 어떤 모양인가요?
# - weights 개수는?

# %%
model = Sequential()
model.add(SimpleRNN(5, batch_input_shape=(8,2,10))) # batch_size=8, timesteps=2, n_feature=10
model.summary()
# Output Shape = batch_size=8, n_feature=5
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (8, 5)                    80
#
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 문제  1-4

# %% [markdown]
# 모델 summary를 보고 생각해봅시다.
# - input은 어떤 모양인가요?
# - output은 어떤 모양인가요?
# - weights 개수는?

# %%
model = Sequential()

model.add(SimpleRNN(5, batch_input_shape=(8,2,10), return_sequences=True)) # batch_size=8, timesteps=2, n_feature=10
model.summary()
# Output Shape = batch_size=8, timesteps=2, n_feature=5
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (8, 2, 5)                 80
#
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 문제 1-5

# %% [markdown]
# output layer를 추가하겠습니다. 그럼 weights의 개수는?

# %%
model = Sequential()
model.add(SimpleRNN(5, input_shape = (2, 10)))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_4 (SimpleRNN)    (None, 5)                 80
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 86
# Trainable params: 86
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 다층 RNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

model = Sequential()
model.add(SimpleRNN(7, input_shape=(100, 5), return_sequences = True))
model.add(SimpleRNN(3))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 100, 7)            91
#
#  simple_rnn_1 (SimpleRNN)    (None, 3)                 33
#
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 128
# Trainable params: 128
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 위의 summary를 보고 직접 계산해보세요

# %% [markdown]
# Wx =
# Wh =
# bh =

# %% [markdown]
# # RNN 구현하기

# %% [markdown]
# - Keras RNN : https://keras.io/api/layers/recurrent_layers/simple_rnn/

# %% [markdown]
# ### 1. 단층 Simple RNN

# %% [markdown]
# 우선 RNN과 LSTM을 테스트하기 위한 임의의 입력을 만듭니다.

# %%
# 단어 벡터
John = [1,0,0,0]
loves = [0,1,0,0]
cats = [0,0,1,0]
dogs = [0,0,0,1]

# %%
# X 데이터

train_X = np.array([
    [ John, loves, cats ],
    [ John, loves, dogs ]
]).astype(np.float32)

# %%
# 타겟 벡터

S = [0] # subject
V = [1] # verb
O = [2] # object

idx2tag = ['S', 'V', 'O']

# %%
# Y 데이터
train_Y = np.array([[S, V, O], [S, V, O]]).astype(np.float32)

print("train_y", train_Y)
print("train_X의 shape", train_X.shape)
print("train_Y의 shape", train_Y.shape)
# Out:
# train_y [[[0.]
#   [1.]
#   [2.]]
#
#  [[0.]
#   [1.]
#   [2.]]]
# train_X의 shape (2, 3, 4)
# train_Y의 shape (2, 3, 1)

# %% [markdown]
# - 단어 벡터의 차원은?
# - 문장의 길이는?
# - output 클래스 개수는?

# %%
from tensorflow.keras import layers, models

model = models.Sequential() #모델 호출
model.add(layers.SimpleRNN(3,
                           input_shape = (3, 4),
                           return_sequences = True,
                           name='SimpleRNN-1')) # RNN 호출

model.add(layers.Dense(3,
                       activation='softmax',
                       name='hidden-to-output')) # 출력을 위한 FFN

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam')

# %%
model.fit(train_X, train_Y, epochs= 50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 1.1265
# Epoch 2/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.1234
# Epoch 3/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1203
# Epoch 4/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1172
# Epoch 5/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1140
# Epoch 6/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1109
# Epoch 7/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1078
# Epoch 8/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.1046
# Epoch 9/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1015
# Epoch 10/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.0984
# Epoch 11/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0952
# Epoch 12/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0921
# Epoch 13/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0890
# Epoch 14/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0858
# Epoch 15/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0827
# Epoch 16/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0795
# Epoch 17/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0764
# Epoch 18/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0732
# Epoch 19/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0701
# Epoch 20/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0669
# Epoch 21/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0638
# Epoch 22/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0606
# Epoch 23/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0575
# Epoch 24/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0543
# Epoch 25/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0511
# Epoch 26/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0480
# Epoch 27/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0448
# Epoch 28/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0417
# Epoch 29/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0385
# Epoch 30/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0353
# Epoch 31/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0322
# Epoch 32/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0290
# Epoch 33/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0258
# Epoch 34/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0227
# Epoch 35/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0195
# Epoch 36/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0163
# Epoch 37/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.0132
# Epoch 38/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0100
# Epoch 39/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0068
# Epoch 40/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0037
# Epoch 41/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0005
# Epoch 42/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9973
# Epoch 43/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.9942
# Epoch 44/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9910
# Epoch 45/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.9879
# Epoch 46/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9847
# Epoch 47/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9815
# Epoch 48/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.9784
# Epoch 49/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9752
# Epoch 50/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9720

# %%
predictions = model.predict(train_X)

for i, prediction in enumerate(predictions):
    print(prediction)
    print(np.argmax(prediction, axis=1))

    result_str = [idx2tag[c] for c in np.argmax(prediction, axis=1) ]

    print("\tPrediction str: ", "".join(result_str), end = '\n\n\n')
# Out:
# 1/1 [==============================] - 0s 221ms/step
# [[0.33519685 0.3826685  0.28213456]
#  [0.29639    0.46468556 0.23892438]
#  [0.27342546 0.5427039  0.18387066]]
# [1 1 1]
# 	Prediction str:  VVV
#
#
# [[0.33519685 0.3826685  0.28213456]
#  [0.29639    0.46468556 0.23892438]
#  [0.35629258 0.2494141  0.39429334]]
# [1 1 2]
# 	Prediction str:  VVO

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  SimpleRNN-1 (SimpleRNN)     (None, 3, 3)              24
#
#  hidden-to-output (Dense)    (None, 3, 3)              12
#
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 실제로 weight의 개수를 확인해봅시다.

# %%
for model_weight in model.weights:
    print(model_weight.name, '=>', model_weight.shape)
# Out:
# SimpleRNN-1/simple_rnn_cell_14/kernel:0 => (4, 3)
# SimpleRNN-1/simple_rnn_cell_14/recurrent_kernel:0 => (3, 3)
# SimpleRNN-1/simple_rnn_cell_14/bias:0 => (3,)
# hidden-to-output/kernel:0 => (3, 3)
# hidden-to-output/bias:0 => (3,)

# %% [markdown]
# ### 2. 다층 Simple RNN

# %% [markdown]
# 임의의 시계열 데이터를 생성하겠습니다.

# %%
import numpy as np

data = np.sin(2*np.pi*np.arange(0, 1000))*10 + np.random.random(1000)
data.shape
# Out:
# (1000,)

# %%
plt.figure(figsize=[100, 20])
plt.plot(np.arange(0, 1000), data)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# X, y 데이터 생성하기

# %% [markdown]
# 다음으로, 해당 샘플 데이터를 1칸씩 이동하며 10개씩 데이터를 잘라, x값으로 사용하고, y값은 11번째 데이터로 사용하겠습니다.
# 예) x = 1번째 ~ 10번째 데이터 / y = 11번째

# %% [markdown]
# 질문) 길이가 1000인 data를 이용해, 몇 쌍의 x, y 데이터를 만들어낼 수 있을까요?

# %%
x_sin = np.array([[[data[i+j]] for j in range(10)] for i in range(len(data)-9-1)])
y_sin = np.array([[data[i+10]] for i in range(len(data)-10)])
x_sin.shape, y_sin.shape
# Out:
# ((990, 10, 1), (990, 1))

# %%
# x_train, x_test, y_train, y_test = train_test_split(x_sin, y_sin, test_size=0.25, random_state=42)

# %%
# shuffle = False로 명시하면, 데이터셋 순차적으로 split
x_train, x_test, y_train, y_test = train_test_split(x_sin, y_sin, shuffle=False)

# %%
x_train.shape, x_test.shape, y_train.shape
# Out:
# ((742, 10, 1), (248, 10, 1), (742, 1))

# %% [markdown]
# ### 모델 작성.
# 1. layer1: SimpleRNN 8
# 2. layer2: SimpleRNN 8
# 3. layer3: SimpleRNN 4
# 4. output_layer:  Dense 1 # 값이 하나 ManyToOne

# %%
model = models.Sequential()

# 다층 RNN
model.add(layers.SimpleRNN(8,
                           input_shape = (10, 1),
                           return_sequences = True,
                           name='SimpleRNN-1'))
model.add(layers.SimpleRNN(8,
                           return_sequences = True,
                           name='SimpleRNN-2'))
model.add(layers.SimpleRNN(4,
                           name='SimpleRNN-3'))

model.add(layers.Dense(1))

model.compile(optimizer='adam', loss='mse')

model.fit(x_train, y_train, epochs=10, batch_size=128, verbose=1)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 5s 16ms/step - loss: 2.2452
# Epoch 2/10
# 6/6 [==============================] - 0s 16ms/step - loss: 1.5427
# Epoch 3/10
# 6/6 [==============================] - 0s 15ms/step - loss: 0.8216
# Epoch 4/10
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4491
# Epoch 5/10
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3701
# Epoch 6/10
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3518
# Epoch 7/10
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3281
# Epoch 8/10
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3017
# Epoch 9/10
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2746
# Epoch 10/10
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2498

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  SimpleRNN-1 (SimpleRNN)     (None, 10, 8)             80
#
#  SimpleRNN-2 (SimpleRNN)     (None, 10, 8)             136
#
#  SimpleRNN-3 (SimpleRNN)     (None, 4)                 52
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - unit: 노드의 개수 (= 아웃풋 공간의 차원)
# - (layer 1) Wx + Wh + b =
# - (layer 2) Wx + Wh + b =
# - (layer 3) Wx + Wh + b =

# %%
for model_weight in model.weights:
    print(model_weight.name, '=>', model_weight.shape)
# Out:
# SimpleRNN-1/simple_rnn_cell_3/kernel:0 => (1, 8)
# SimpleRNN-1/simple_rnn_cell_3/recurrent_kernel:0 => (8, 8)
# SimpleRNN-1/simple_rnn_cell_3/bias:0 => (8,)
# SimpleRNN-2/simple_rnn_cell_4/kernel:0 => (8, 8)
# SimpleRNN-2/simple_rnn_cell_4/recurrent_kernel:0 => (8, 8)
# SimpleRNN-2/simple_rnn_cell_4/bias:0 => (8,)
# SimpleRNN-3/simple_rnn_cell_5/kernel:0 => (8, 4)
# SimpleRNN-3/simple_rnn_cell_5/recurrent_kernel:0 => (4, 4)
# SimpleRNN-3/simple_rnn_cell_5/bias:0 => (4,)
# dense_1/kernel:0 => (4, 1)
# dense_1/bias:0 => (1,)

# %%
model.weights
# Out:
# [<tf.Variable 'SimpleRNN-1/simple_rnn_cell_3/kernel:0' shape=(1, 8) dtype=float32, numpy=
#  array([[ 0.00962886,  0.26808962, -0.34948006, -0.63305676,  0.7752815 ,
#          -0.01655496,  0.7271438 , -0.44414356]], dtype=float32)>,
#  <tf.Variable 'SimpleRNN-1/simple_rnn_cell_3/recurrent_kernel:0' shape=(8, 8) dtype=float32, numpy=
#  array([[ 0.4873382 ,  0.0715445 , -0.00352842, -0.52184856, -0.28514794,
#          -0.06421236,  0.46200848,  0.3108914 ],
#         [-0.05948351, -0.1201278 , -0.6992119 ,  0.274175  , -0.2121879 ,
#          -0.4308369 ,  0.33837163, -0.14786728],
#         [ 0.32545534, -0.39847746, -0.4369227 , -0.1856929 , -0.11021267,
#           0.25154808, -0.61983645,  0.1522791 ],
#         [ 0.14706378,  0.07257415,  0.0442837 , -0.16953063,  0.62937325,
#          -0.62160826, -0.22685714,  0.19352387],
#         [ 0.29983976,  0.7146216 , -0.36797357, -0.0271247 ,  0.18295436,
#           0.2174265 , -0.07664338, -0.20964189],
#         [ 0.11727978,  0.26706132,  0.11183723,  0.53743744, -0.23068433,
#          -0.06448656, -0.20100623,  0.68923706],
#         [ 0.3283858 ,  0.11840247,  0.29556802,  0.05149333, -0.505031  ,
#          -0.42870644, -0.2649997 , -0.5351906 ],
#         [ 0.6299918 , -0.32524127,  0.10580362,  0.49162906,  0.36875114,
#           0.21135737,  0.24446051, -0.12424345]], dtype=float32)>,
#  <tf.Variable 'SimpleRNN-1/simple_rnn_cell_3/bias:0' shape=(8,) dtype=float32, numpy=
#  array([ 0.01255891,  0.02591846,  0.01599965, -0.03325479, -0.036422  ,
#         -0.02520585,  0.04201194, -0.01326289], dtype=float32)>,
#  <tf.Variable 'SimpleRNN-2/simple_rnn_cell_4/kernel:0' shape=(8, 8) dtype=float32, numpy=
#  array([[-0.17631865, -0.1366316 ,  0.5122379 , -0.5549191 ,  0.00738714,
#          -0.5798913 ,  0.27913478, -0.18321793],
#         [-0.21191455, -0.25516042,  0.14565894,  0.27164006, -0.08426708,
#           0.05920497, -0.10805392,  0.04677232],
#         [ 0.39775783, -0.10981602,  0.47618186,  0.23333122, -0.38976568,
#           0.41093636, -0.57037413,  0.21586362],
#         [-0.57765096, -0.5263658 , -0.30058417, -0.07479937, -0.4853504 ,
#           0.1424241 ,  0.5350933 , -0.20956582],
#         [-0.5414278 ,  0.23691133,  0.339728  , -0.5588521 , -0.3749396 ,
#          -0.48647568,  0.24294767, -0.4611656 ],
#         [-0.13188113,  0.0283997 ,  0.08280679,  0.5397548 ,  0.52709895,
#          -0.02742699, -0.29176897, -0.10954607],
#         [-0.33473554,  0.22558519,  0.1737421 , -0.45457518,  0.19342801,
#           0.27934483,  0.13627328, -0.28778914],
#         [ 0.31759247,  0.1070709 , -0.02758881,  0.26062474, -0.0892438 ,
#          -0.44782588,  0.18982956, -0.33834252]], dtype=float32)>,
#  <tf.Variable 'SimpleRNN-2/simple_rnn_cell_4/recurrent_kernel:0' shape=(8, 8) dtype=float32, numpy=
#  array([[ 0.18170151, -0.02563129,  0.44810203, -0.09727082,  0.29393783,
#           0.22366503, -0.10596484,  0.76436603],
#         [ 0.22623275, -0.29368705,  0.15575373,  0.4745264 , -0.4296145 ,
#          -0.5734619 , -0.1882336 ,  0.21799566],
#         [-0.29146308, -0.3863723 ,  0.25889742,  0.54924273,  0.40973282,
#           0.25044173, -0.15544707, -0.33137307],
#         [-0.13634403,  0.04704403,  0.6319649 , -0.04753849, -0.5735901 ,
#           0.26341996,  0.1675334 , -0.19013359],
#         [ 0.0337972 , -0.29161775,  0.02644982,  0.18519813,  0.14845204,
#          -0.09601545,  0.954547  ,  0.11565056],
#         [ 0.51807773,  0.33741653, -0.33493692,  0.48761925, -0.29748133,
#           0.58854514, -0.03409454,  0.10795154],
#         [-0.5340648 ,  0.658074  ,  0.11037841,  0.32229987,  0.08629617,
#          -0.2027994 ,  0.18296295,  0.16689296],
#         [-0.56214327, -0.31678405, -0.4018389 ,  0.03415448, -0.37110397,
#           0.36136034, -0.10232488,  0.42630196]], dtype=float32)>,
#  <tf.Variable 'SimpleRNN-2/simple_rnn_cell_4/bias:0' shape=(8,) dtype=float32, numpy=
#  array([ 0.04577241, -0.01989381,  0.00757038,  0.01533534, -0.04576218,
#          0.03946556, -0.04027199, -0.01434389], dtype=float32)>,
#  <tf.Variable 'SimpleRNN-3/simple_rnn_cell_5/kernel:0' shape=(8, 4) dtype=float32, numpy=
#  array([[ 0.37440905, -0.52650493, -0.6815096 ,  0.6440223 ],
#         [ 0.26486218,  0.44855404,  0.43183532,  0.31860977],
#         [ 0.22223747, -0.5738151 ,  0.67393565,  0.61120695],
#         [ 0.20352848,  0.49003568,  0.47360075,  0.35306624],
#         [ 0.33253568, -0.07340027,  0.45909745,  0.62612665],
#         [ 0.32457384, -0.45415354, -0.19179602, -0.5410537 ],
#         [ 0.00928456,  0.18540694, -0.15742439,  0.68796694],
#         [-0.1284182 ,  0.58002925,  0.03283384, -0.36426997]],
#        dtype=float32)>,
#  <tf.Variable 'SimpleRNN-3/simple_rnn_cell_5/recurrent_kernel:0' shape=(4, 4) dtype=float32, numpy=
#  array([[-0.4226867 , -0.07232685, -0.6002086 ,  0.7326427 ],
#         [ 0.48403424,  0.6518417 , -0.5177971 , -0.04082002],
#         [-0.75363487,  0.7113385 ,  0.12913203, -0.17184986],
#         [ 0.19474924,  0.42240804,  0.6370822 ,  0.6837192 ]],
#        dtype=float32)>,
#  <tf.Variable 'SimpleRNN-3/simple_rnn_cell_5/bias:0' shape=(4,) dtype=float32, numpy=array([ 0.05412512, -0.03099649, -0.05639116,  0.01794543], dtype=float32)>,
#  <tf.Variable 'dense_1/kernel:0' shape=(4, 1) dtype=float32, numpy=
#  array([[-0.5253605 ],
#         [ 0.8811991 ],
#         [-0.8932081 ],
#         [-0.60911196]], dtype=float32)>,
#  <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([-0.05762862], dtype=float32)>]

# %% [markdown]
# ##### 학습결과

# %%
y_hat = model.predict(x_test) #테스트값 예측
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %%
y_axis = np.arange(0, len(y_train))
y_2_axis = np.arange(len(y_train), len(y_train)+len(y_hat))

plt.figure(figsize = (100,30))
# Train 데이터 그래프로 표현
plt.plot(y_axis, y_train.reshape(len(x_train),), '-o')
plt.plot(y_2_axis, y_hat.reshape(len(x_test),),'-o', color = 'red', label = 'predicted')
plt.plot(y_2_axis, y_test.reshape(len(x_test),), '-o', color = 'purple', alpha = 0.3, label = 'actual')
plt.legend(fontsize = 40)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### reference

# %% [markdown]
# - https://github.com/ukairia777/tensorflow-nlp-tutorial/blob/main/08.%20RNN/8-4.%20understanding_simplernn_and_lstm.ipynb
